# %%
import hashlib as hasher
import datetime as date


class Block:
    def __init__(self, index, timestamp, data, previous_hash):
        self.index = index
        self.timestamp = timestamp
        self.data = data
        self.previous_hash = previous_hash
        self.hash = self.hash_block()

    def hash_block(self):
        sha = hasher.sha256()
        shastr = str(self.index) + str(self.timestamp) + str(self.data) + str(self.previous_hash)
        sha.update(shastr.encode('utf-8'))
        return sha.hexdigest()


def create_genesis_block():
    # Manually construct a block with index zero and arbitrary previous hash
    return Block(0, date.datetime.now(), "Genesis Block", '0')


def next_block(last_block):
    this_index = last_block.index + 1
    this_timestamp = date.datetime.now()
    this_data = "Hey! I'm block " + str(this_index)
    this_hash = last_block.hash
    return Block(this_index, this_timestamp, this_data, this_hash)

# %%
# Create the blockchain and add the genesis block
blockchain = [create_genesis_block()]
previous_block = blockchain[0]

# How many blocks should we add to the chain after the genesis block
num_of_blocks_to_add = 10

# Add blocks to the chain
for i in range(0, num_of_blocks_to_add):
    block_to_add = next_block(previous_block)
    blockchain.append(block_to_add)
    previous_block = block_to_add
    # Tell everyone about it!
    print("Block index {} has been added to the blockchain!".format(block_to_add.index))
    print("Block TimeStamp: {}".format(block_to_add.timestamp))
    print("Block Data: {}".format(block_to_add.data))
    print("Block previous_hash: {}".format(block_to_add.previous_hash))
    print("Block Hash: {}\n".format(block_to_add.hash))
# Out:
# Block index 1 has been added to the blockchain!
# Block TimeStamp: 2019-11-05 12:11:34.935931
# Block Data: Hey! I'm block 1
# Block previous_hash: de978ae04c4ea00ed698131ea88b2749d44ab306753ad8124911687fbd54a73f
# Block Hash: f475e937930378652c24bf931466277e6d4724a9b02812d4c2bfa852a7c99ca3
#
# Block index 2 has been added to the blockchain!
# Block TimeStamp: 2019-11-05 12:11:34.936928
# Block Data: Hey! I'm block 2
# Block previous_hash: f475e937930378652c24bf931466277e6d4724a9b02812d4c2bfa852a7c99ca3
# Block Hash: 01e4b5f808ad71ebfee487032a7ef5f82371f1af0a95cbc35772f4e845f592c2
#
# Block index 3 has been added to the blockchain!
# Block TimeStamp: 2019-11-05 12:11:34.936928
# Block Data: Hey! I'm block 3
# Block previous_hash: 01e4b5f808ad71ebfee487032a7ef5f82371f1af0a95cbc35772f4e845f592c2
# Block Hash: d80805dc4b76fdba853e2b337c54893e6ebc035829c83a0e4e21cc004e210aec
#
# Block index 4 has been added to the blockchain!
# Block TimeStamp: 2019-11-05 12:11:34.936928
# Block Data: Hey! I'm block 4
# Block previous_hash: d80805dc4b76fdba853e2b337c54893e6ebc035829c83a0e4e21cc004e210aec
# Block Hash: 7366b3bbaa2b96b1b09f3086941624f6963645876f88f1fa2e046815e0d0e0ce
#
# Block index 5 has been added to the blockchain!
# Block TimeStamp: 2019-11-05 12:11:34.937938
# Block Data: Hey! I'm block 5
# Block previous_hash: 7366b3bbaa2b96b1b09f3086941624f6963645876f88f1fa2e046815e0d0e0ce
# Block Hash: b4db96ed1634ae9917eb1dfa1681a101af8e48c8ace1b4932e3ae60b659f3428
#
# Block index 6 has been added to the blockchain!
# Block TimeStamp: 2019-11-05 12:11:34.937938
# Block Data: Hey! I'm block 6
# Block previous_hash: b4db96ed1634ae9917eb1dfa1681a101af8e48c8ace1b4932e3ae60b659f3428
# Block Hash: 0afa0169ffa4f18c1cb31bfa29ad53e9a6026789cde4b550d01f9e112574dfb0
#
# Block index 7 has been added to the blockchain!
# Block TimeStamp: 2019-11-05 12:11:34.937938
# Block Data: Hey! I'm block 7
# Block previous_hash: 0afa0169ffa4f18c1cb31bfa29ad53e9a6026789cde4b550d01f9e112574dfb0
# Block Hash: cbcc3eea8c3363a54ee8b2c39ccf0cc8ce6b5495cac3a7ba05a01a4007cad3f9
#
# Block index 8 has been added to the blockchain!
# Block TimeStamp: 2019-11-05 12:11:34.937938
# Block Data: Hey! I'm block 8
# Block previous_hash: cbcc3eea8c3363a54ee8b2c39ccf0cc8ce6b5495cac3a7ba05a01a4007cad3f9
# Block Hash: e6fffdfe38c4d0d2942f6d04b00383265d70ccf9407555a983448440c55493a3
#
# Block index 9 has been added to the blockchain!
# Block TimeStamp: 2019-11-05 12:11:34.938923
# Block Data: Hey! I'm block 9
# Block previous_hash: e6fffdfe38c4d0d2942f6d04b00383265d70ccf9407555a983448440c55493a3
# Block Hash: 02ecc679aeabeca94c8ad2e0c1c94c6c68222ced5c220d6237588928f5d96168
#
# Block index 10 has been added to the blockchain!
# Block TimeStamp: 2019-11-05 12:11:34.938923
# Block Data: Hey! I'm block 10
# Block previous_hash: 02ecc679aeabeca94c8ad2e0c1c94c6c68222ced5c220d6237588928f5d96168
# Block Hash: 4c5d2b9f6568d2c3378f42eaf912d042ccaefbab601f9e5dc2b9583092796d4c
